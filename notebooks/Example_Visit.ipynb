# %%
from lsst.daf.butler import Butler
from lsst.obs.lsst import LsstCam

repo = "/sdf/data/rubin/repo/dp2_prep"
collections = "u/snyder18/DRP/detectAndMeasureDiaSource"
instrument = LsstCam().getCamera().getName()

visit = 2025071700631
detector_id = 140  # additional detector_id = 136

butler = Butler(repo, collections=collections, instrument=instrument)
diffim = butler.get("difference_image", instrument=instrument, visit=visit, detector=detector_id)
